# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from sqlalchemy import create_engine

# %matplotlib inline

sns.set_style("whitegrid")

plt.rcParams["figure.figsize"] = (12,6)

# %%
profit_loss = pd.read_csv(
    r"C:\Users\sujit\OneDrive\Documents\financial-intelligence-system\exports\clean_profit_loss.csv"
)

balance_sheet = pd.read_csv(
    r"C:\Users\sujit\OneDrive\Documents\financial-intelligence-system\exports\clean_balance_sheet.csv"
)

cash_flow = pd.read_csv(
    r"C:\Users\sujit\OneDrive\Documents\financial-intelligence-system\exports\clean_cash_flow.csv"
)

analysis = pd.read_csv(
    r"C:\Users\sujit\OneDrive\Documents\financial-intelligence-system\exports\clean_analysis.csv"
)

# %%
profit_loss.head()
# Out:
#    id company_id      year  sales  expenses  operating_profit  opm_percentage  \
# 0  61        ABB  Dec 2012   1653      1451             202.0            12.0
# 1  62        ABB  Mar 2014   2276      2009             267.0            12.0
# 2  63        ABB  Mar 2015   2289      1977             312.0            14.0
# 3  64        ABB  Mar 2016   2614      2250             365.0            14.0
# 4  65        ABB  Mar 2017   2903      2505             398.0            14.0
#
#    other_income  interest  depreciation  profit_before_tax  tax_percentage  \
# 0            33         0            19                215            33.0
# 1            49         0            22                295            33.0
# 2            48         0            15                344            34.0
# 3            50         3            14                398            36.0
# 4            57         2            16                436            37.0
#
# ...

# %%
profit_loss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1276 non-null   int64
#  1   company_id         1276 non-null   object
#  2   year               1276 non-null   object
#  3   sales              1276 non-null   int64
#  4   expenses           1276 non-null   int64
#  5   operating_profit   1263 non-null   float64
#  6   opm_percentage     1261 non-null   float64
#  7   other_income       1276 non-null   int64
#  8   interest           1276 non-null   int64
#  9   depreciation       1276 non-null   int64
#  10  profit_before_tax  1276 non-null   int64
#  11  tax_percentage     1181 non-null   float64
#  12  net_profit         1276 non-null   int64
#  13  eps                1271 non-null   float64
#  14  dividend_payout    1173 non-null   float64
#  15  net_margin         1275 non-null   float64
# ...

# %%
profit_loss.describe()
# Out:
#                 id          sales       expenses  operating_profit  \
# count  1276.000000    1276.000000    1276.000000       1263.000000
# mean    724.192790   64366.308777   46790.302508      14621.886778
# std     379.978128  115696.774399  103593.923463      25127.504122
# min      61.000000       0.000000    -366.000000     -86697.000000
# 25%     391.750000    9830.750000    4301.750000       1825.000000
# 50%     736.500000   25803.500000   12069.500000       5473.000000
# 75%    1055.250000   68264.750000   40377.500000      19312.000000
# max    1374.000000  939838.000000  870255.000000     206009.000000
#
#        opm_percentage   other_income       interest  depreciation  \
# count     1261.000000    1276.000000    1276.000000   1276.000000
# mean       349.936558    2006.887931    6290.561912   2408.515674
# std       5819.466560   10169.442228   20425.108328   5261.460086
# min     -57587.000000  -37775.000000    -987.000000      0.000000
# ...

# %%
profit_loss.isnull().sum()
# Out:
# id                     0
# company_id             0
# year                   0
# sales                  0
# expenses               0
# operating_profit      13
# opm_percentage        15
# other_income           0
# interest               0
# depreciation           0
# profit_before_tax      0
# tax_percentage        95
# net_profit             0
# eps                    5
# dividend_payout      103
# net_margin             1
# operating_margin      14
# interest_burden        1
# dtype: int64

# %%
plt.figure(figsize=(12,6))

sns.histplot(
    profit_loss["sales"],
    bins=50,
    kde=True
)

plt.title("Revenue Distribution Across Companies")
plt.xlabel("Sales")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(12,4))

sns.boxplot(
    x=profit_loss["sales"]
)

plt.title("Revenue Boxplot")

plt.show()

# %%
top_revenue = (
    profit_loss.groupby("company_id")["sales"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

top_revenue.plot(
    kind="bar",
    color="blue"
)

plt.title("Top 10 Companies by Revenue")

plt.show()

# %%
bottom_revenue = (
    profit_loss.groupby("company_id")["sales"]
    .sum()
    .sort_values(ascending=True)
    .head(10)
)

bottom_revenue.plot(
    kind="bar",
    color="red"
)

plt.title("Bottom 10 Companies by Revenue")

plt.show()

# %%
profit_loss["net_margin"] = (
    profit_loss["net_profit"] /
    profit_loss["sales"]
) * 100

# %%
top_margin = (
    profit_loss.groupby("company_id")["net_margin"]
    .mean()
    .sort_values(ascending=False)
    .head(10)
)

top_margin.plot(
    kind="bar",
    color="green"
)

plt.title("Top Net Profit Margin Companies")

plt.show()

# %%
sns.histplot(
    profit_loss["opm_percentage"],
    bins=40,
    kde=True
)

plt.title("Operating Profit Margin Distribution")

plt.show()

# %%
top_opm = (
    profit_loss.groupby("company_id")["opm_percentage"]
    .mean()
    .sort_values(ascending=False)
    .head(10)
)

top_opm.plot(
    kind="bar",
    color="purple"
)

plt.title("Top OPM Companies")

plt.show()

# %%
balance_sheet["roe"] = (
    balance_sheet["reserves"] /
    balance_sheet["equity_capital"]
) * 100

# %%
top_roe = (
    balance_sheet.groupby("company_id")["roe"]
    .mean()
    .sort_values(ascending=False)
    .head(10)
)

top_roe.plot(
    kind="bar",
    color="orange"
)

plt.title("Top ROE Companies")

plt.show()

# %%
merged = profit_loss.merge(
    balance_sheet,
    on=["company_id", "year"],
    how="inner"
)

# %%
numeric_cols = merged.select_dtypes(include=np.number)

corr = numeric_cols.corr()

plt.figure(figsize=(14,10))

sns.heatmap(
    corr,
    cmap="coolwarm"
)

plt.title("Correlation Matrix")

plt.show()

# %%
plt.figure(figsize=(14,6))

sns.heatmap(
    profit_loss.isnull(),
    cbar=False,
    cmap="viridis"
)

plt.title("Missing Values Heatmap")

plt.show()

# %%
year_coverage = (
    profit_loss.groupby("company_id")["year"]
    .count()
    .sort_values(ascending=False)
)

year_coverage.head(20).plot(
    kind="bar",
    color="teal"
)

plt.title("Top Companies by Historical Year Coverage")

plt.ylabel("Number of Years")

plt.show()

# %%
sales_growth = (
    profit_loss.groupby("company_id")["sales"]
    .agg(["first", "last"])
)

sales_growth["growth_rate"] = (
    (
        sales_growth["last"] -
        sales_growth["first"]
    )
    /
    sales_growth["first"]
) * 100

# %%
sns.histplot(
    sales_growth["growth_rate"],
    bins=40,
    kde=True
)

plt.title("Sales Growth Distribution")

plt.xlabel("Growth %")

plt.show()

# %%
top_growth = (
    sales_growth["growth_rate"]
    .sort_values(ascending=False)
    .head(10)
)

top_growth.plot(
    kind="bar",
    color="darkgreen"
)

plt.title("Top Sales Growth Companies")

plt.show()

# %%
bottom_growth = (
    sales_growth["growth_rate"]
    .sort_values(ascending=True)
    .head(10)
)

bottom_growth.plot(
    kind="bar",
    color="darkred"
)

plt.title("Bottom Sales Growth Companies")

plt.show()

# %%
balance_sheet["debt_to_equity"] = (
    balance_sheet["borrowings"] /
    (
        balance_sheet["equity_capital"] +
        balance_sheet["reserves"]
    )
)

# %%
sns.boxplot(
    x=balance_sheet["debt_to_equity"]
)

plt.title("Debt to Equity Distribution")

plt.show()

# %%
plt.figure(figsize=(12,6))

sns.scatterplot(
    data=profit_loss,
    x="sales",
    y="net_profit"
)

plt.title("Sales vs Net Profit")

plt.show()

# %%
interactive_chart = px.scatter(
    profit_loss,
    x="sales",
    y="net_profit",
    color="company_id",
    title="Interactive Sales vs Net Profit"
)

interactive_chart.show()

# %%
analysis.columns
# Out:
# Index(['id', 'company_id', 'compounded_sales_growth',
#        'compounded_profit_growth', 'stock_price_cagr', 'roe'],
#       dtype='object')
