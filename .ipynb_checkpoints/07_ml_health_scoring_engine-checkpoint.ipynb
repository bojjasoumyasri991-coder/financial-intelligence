# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from sklearn.preprocessing import MinMaxScaler
from scipy.stats import percentileofscore

from sklearn.linear_model import LinearRegression

# %%
profit_loss = pd.read_csv(
    "exports/clean_profit_loss.csv"
)

balance_sheet = pd.read_csv(
    "exports/clean_balance_sheet.csv"
)

cash_flow = pd.read_csv(
    "exports/clean_cash_flow.csv"
)

analysis = pd.read_csv(
    "exports/clean_analysis.csv"
)

# %%
profitability = (
    profit_loss.groupby("company_id")
    .agg({
        "opm_percentage":"mean",
        "net_margin":"mean"
    })
)

# %%
balance_sheet["roe"] = (
    balance_sheet["reserves"] /
    (
        balance_sheet["equity_capital"] + 1
    )
) * 100

# %%
roe = (
    balance_sheet.groupby("company_id")
    ["roe"]
    .mean()
)

# %%
profitability = profitability.merge(
    roe,
    on="company_id",
    how="left"
)

# %%
profitability["opm_score"] = (
    profitability["opm_percentage"]
    .rank(pct=True)
)

profitability["margin_score"] = (
    profitability["net_margin"]
    .rank(pct=True)
)

profitability["roe_score"] = (
    profitability["roe"]
    .rank(pct=True)
)

# %%
profitability["profitability_score"] = (
    (
        profitability["opm_score"] +
        profitability["margin_score"] +
        profitability["roe_score"]
    ) / 3
) * 25

# %%
sales_growth = (
    profit_loss.groupby("company_id")
    ["sales"]
    .agg(["first","last"])
)

# %%
sales_growth["growth_3y"] = (
    (
        sales_growth["last"] /
        (sales_growth["first"] + 1)
    ) ** (1/3) - 1
) * 100

# %%
def growth_score(g):

    if g < 0:
        return 0

    elif g < 5:
        return 5

    elif g >= 20:
        return 20

    else:
        return (g / 20) * 20

# %%
sales_growth["growth_score"] = (
    sales_growth["growth_3y"]
    .apply(growth_score)
)

# %%
balance_sheet["de_ratio"] = (
    balance_sheet["borrowings"] /
    (
        balance_sheet["equity_capital"] +
        balance_sheet["reserves"] + 1
    )
)

# %%
debt = (
    balance_sheet.groupby("company_id")
    ["de_ratio"]
    .mean()
)

# %%
def debt_score(x):

    if x < 0.1:
        return 20

    elif x > 2:
        return 0

    else:
        return 20 * (1 - (x / 2))

# %%
debt = debt.to_frame()

debt["debt_score"] = (
    debt["de_ratio"]
    .apply(debt_score)
)

# %%
cash_merged = cash_flow.merge(
    profit_loss[
        [
            "company_id",
            "year",
            "net_profit"
        ]
    ],
    on=["company_id","year"],
    how="left"
)

# %%
cash_merged["cash_conversion"] = (
    cash_merged["operating_activity"] /
    (
        cash_merged["net_profit"] + 1
    )
)

# %%
cash_conversion = (
    cash_merged.groupby("company_id")
    ["cash_conversion"]
    .mean()
)

# %%
def cash_score(x):

    if x >= 1.2:
        return 15

    elif x <= 0:
        return 0

    else:
        return (x / 1.2) * 15

# %%
dividend = (
    profit_loss.groupby("company_id")
    ["dividend_payout"]
    .mean()
)

# %%
def dividend_score(x):

    if x >= 30:
        return 10

    elif x <= 0:
        return 0

    else:
        return (x / 30) * 10

# %%
dividend = dividend.to_frame()

dividend["dividend_score"] = (
    dividend["dividend_payout"]
    .apply(dividend_score)
)

# %%
trend_scores = []

# %%
for company in profit_loss["company_id"].unique():

    company_data = (
        profit_loss[
            profit_loss["company_id"] == company
        ]
        .sort_values("year")
        .tail(5)
    )

    if len(company_data) < 3:
        continue

    X = np.arange(len(company_data)).reshape(-1,1)

    y = company_data["sales"].values

    model = LinearRegression()

    model.fit(X,y)

    slope = model.coef_[0]

    if slope > 0:
        score = 10
    else:
        score = 0

    trend_scores.append({
        "company_id":company,
        "trend_score":score
    })

# %%
trend_df = pd.DataFrame(
    trend_scores
)

# %%
final_scores = profitability[
    ["profitability_score"]
].copy()

# %%
cash_conversion = cash_conversion.to_frame()

# %%
cash_conversion["cash_score"] = (
    cash_conversion["cash_conversion"]
    .apply(cash_score)
)

# %%
final_scores = final_scores.merge(
    cash_conversion[["cash_score"]],
    on="company_id"
)

# %%
dividend["dividend_score"] = (
    dividend["dividend_payout"]
    .apply(dividend_score)
)

# %%
final_scores = final_scores.merge(
    dividend[["dividend_score"]],
    on="company_id"
)

# %%
final_scores = final_scores.merge(
    trend_df,
    on="company_id"
)

# %%
final_scores.columns
# Out:
# Index(['company_id', 'profitability_score', 'growth_score', 'debt_score',
#        'cash_score', 'dividend_score', 'trend_score'],
#       dtype='object')

# %%
final_scores["health_score"] = (

    final_scores["profitability_score"] +

    final_scores["growth_score"] +

    final_scores["debt_score"] +

    final_scores["cash_score"] +

    final_scores["dividend_score"] +

    final_scores["trend_score"]

)

# %%
def label(score):

    if score >= 85:
        return "EXCELLENT"

    elif score >= 70:
        return "GOOD"

    elif score >= 50:
        return "AVERAGE"

    elif score >= 35:
        return "WEAK"

    else:
        return "POOR"

# %%
final_scores["label"] = (
    final_scores["health_score"]
    .apply(label)
)

# %%
plt.figure(figsize=(12,6))

sns.histplot(
    final_scores["health_score"],
    bins=20,
    kde=True
)

plt.title(
    "ML Financial Health Score Distribution"
)

plt.show()

# %%
final_scores.sort_values(
    "health_score",
    ascending=False
).head(20)
# Out:
#     company_id  profitability_score  growth_score  debt_score  cash_score  \
# 41  HINDUNILVR            19.107160     20.000000   20.000000   13.240622
# 79   SUNPHARMA            19.109101     20.000000   18.413248   15.000000
# 26    DIVISLAB            20.274892     20.000000   20.000000   11.168100
# 84         TCS            19.529204     20.000000   20.000000   11.825030
# 36     HCLTECH            17.002061     20.000000   20.000000   14.314730
# 24   COALINDIA            15.848639     20.000000   20.000000   14.867999
# 30   EICHERMOT            19.289494     20.000000   20.000000   13.520391
# 39  HEROMOTOCO            19.319762     16.628526   20.000000   13.742884
# 51         ITC            17.041040     20.000000   20.000000   12.091645
# 60        LTIM            16.773861     20.000000   20.000000   12.010149
# 0          ABB            13.596200     20.000000   20.000000   15.000000
# 53      JIOFIN            23.318182     20.000000   20.000000   15.000000
# ...

# %%
final_scores.to_csv(
    "exports/ml_health_scores.csv",
    index=False
)
